# %%
import pandas as pd
import numpy as np
import os
from tqdm import tqdm

## To keep the plots even after closing the notebook
import plotly.io as pio
pio.renderers.default='notebook'

# %%
folder_path = 'output/'
# list all files in the directory
files = os.listdir(folder_path)

# filter files that start with 'Take_2' and end with '.csv'
filtered_files = [file for file in files if file.startswith('Take_2') and file.endswith('.csv')]
filtered_files.sort()
# print the list of filtered files
filtered_files
# Out:
# ['Take_2_2006Fall_2017Spring_GOES_meteo_combined_04839.csv',
#  'Take_2_2006Fall_2017Spring_GOES_meteo_combined_04846.csv',
#  'Take_2_2006Fall_2017Spring_GOES_meteo_combined_04877.csv',
#  'Take_2_2006Fall_2017Spring_GOES_meteo_combined_04892.csv',
#  'Take_2_2006Fall_2017Spring_GOES_meteo_combined_14815.csv',
#  'Take_2_2006Fall_2017Spring_GOES_meteo_combined_14819.csv',
#  'Take_2_2006Fall_2017Spring_GOES_meteo_combined_14829.csv',
#  'Take_2_2006Fall_2017Spring_GOES_meteo_combined_14836.csv',
#  'Take_2_2006Fall_2017Spring_GOES_meteo_combined_14840.csv',
#  'Take_2_2006Fall_2017Spring_GOES_meteo_combined_14841.csv',
#  'Take_2_2006Fall_2017Spring_GOES_meteo_combined_14845.csv',
#  'Take_2_2006Fall_2017Spring_GOES_meteo_combined_14848.csv',
#  'Take_2_2006Fall_2017Spring_GOES_meteo_combined_14850.csv',
#  'Take_2_2006Fall_2017Spring_GOES_meteo_combined_94814.csv',
#  'Take_2_2006Fall_2017Spring_GOES_meteo_combined_94815.csv',
# ...

# %%
len(filtered_files)
# Out:
# 18

# %%
filename = filtered_files[16]
filename
# Out:
# 'Take_2_2006Fall_2017Spring_GOES_meteo_combined_94871.csv'

# %%
file_path = 'output/'

df_temp_table = pd.read_csv(file_path+filename)

df_temp_table.head(5)
# Out:
#      Date_UTC Time_UTC    Date_CST Time_CST  \
# 0  2006-10-01    00:00  2006-09-30    18:00
# 1  2006-10-01    01:00  2006-09-30    19:00
# 2  2006-10-01    02:00  2006-09-30    20:00
# 3  2006-10-01    03:00  2006-09-30    21:00
# 4  2006-10-01    04:00  2006-09-30    22:00
#
#                        File_name_for_1D_lake  \
# 0  goes11.2006.10.01.0000.v01.nc-var1-t0.csv
# 1  goes11.2006.10.01.0100.v01.nc-var1-t0.csv
# 2  goes11.2006.10.01.0200.v01.nc-var1-t0.csv
# 3  goes11.2006.10.01.0300.v01.nc-var1-t0.csv
# 4  goes11.2006.10.01.0400.v01.nc-var1-t0.csv
#
#                              File_name_for_2D_lake  \
# 0  T_goes11.2006.10.01.0000.v01.nc-var1-t0.csv.csv
# 1  T_goes11.2006.10.01.0100.v01.nc-var1-t0.csv.csv
# 2  T_goes11.2006.10.01.0200.v01.nc-var1-t0.csv.csv
# 3  T_goes11.2006.10.01.0300.v01.nc-var1-t0.csv.csv
# 4  T_goes11.2006.10.01.0400.v01.nc-var1-t0.csv.csv
#
#                                         Lake_data_1D  data_usable  \
# ...

# %%
## Inspection use only

df_temp_table['data_usable'].value_counts()
# Out:
# True     24904
# False    23220
# Name: data_usable, dtype: int64

# %%
# Define the time UTC values to exclude
exclude_utc_values = ['21:00', '22:00', '23:00', '00:00', '01:00', '02:00', '03:00', '04:00', '05:00', '06:00',
                      '07:00', '08:00', '09:00', '10:00', '11:00', '12:00', '13:00']

# Filter the dataframe based on the exclusion of time UTC values
filtered_df = df_temp_table[~df_temp_table['Time_UTC'].isin(exclude_utc_values)]

# Check the distribution of values in the 'data_usable' column
distribution = filtered_df['data_usable'].value_counts()

distribution
# Out:
# True     13867
# False      170
# Name: data_usable, dtype: int64

# %%
filtered_df = filtered_df.drop('Unnamed: 18', axis=1)

# %%
filtered_df['event_year'] = filtered_df['Date_UTC'].str[:4]

# %%
# Filter the dataframe based on the condition
filtered_rows = filtered_df[(filtered_df['data_usable'] == False) & (filtered_df['Date_UTC'].str.startswith('2011'))]

filtered_rows
# Out:
#          Date_UTC Time_UTC    Date_CST Time_CST  \
# 20229  2011-01-22    19:00  2011-01-22    13:00
# 20230  2011-01-22    20:00  2011-01-22    14:00
# 20922  2011-02-20    16:00  2011-02-20    10:00
# 20923  2011-02-20    17:00  2011-02-20    11:00
# 20925  2011-02-20    19:00  2011-02-20    13:00
# ...           ...      ...         ...      ...
# 23465  2011-12-06    15:00  2011-12-06    09:00
# 23489  2011-12-07    15:00  2011-12-07    09:00
# 23518  2011-12-08    20:00  2011-12-08    14:00
# 23637  2011-12-13    19:00  2011-12-13    13:00
# 23686  2011-12-15    20:00  2011-12-15    14:00
#
#                         File_name_for_1D_lake  \
# 20229  goes13.2011.01.22.1900.v01.nc-var0.csv
# 20230  goes13.2011.01.22.2000.v01.nc-var0.csv
# 20922  goes13.2011.02.20.1600.v01.nc-var0.csv
# 20923  goes13.2011.02.20.1700.v01.nc-var0.csv
# 20925  goes13.2011.02.20.1900.v01.nc-var0.csv
# ...                                       ...
# 23465                                    None
# ...

# %%
df_unusable_data = filtered_df[filtered_df['data_usable'] == False]

df_unusable_data['event_year'].value_counts()
# Out:
# 2011    75
# 2010    36
# 2009    34
# 2012    12
# 2008     5
# 2015     4
# 2007     3
# 2006     1
# Name: event_year, dtype: int64

# %%
df_unusable_data.to_csv('output/unusable_data_rev_2.csv', index=False)

# %% [markdown]
# ---
#
# ## Testing Area

# %%
file_str = 'goes15.2016.12.08.1200.v01.nc-var1-t0.csv'

# %%
from tqdm import tqdm
index_pack = [np.array(i) for i in range(9)]
for i in tqdm(index_pack):
    print(i)
# Out:
# 100%|██████████| 9/9 [00:00<00:00, 16732.60it/s]
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
