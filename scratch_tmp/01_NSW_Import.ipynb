# %%
import pandas
import os

# %%
# Test
temp_table = pandas.read_csv('NSW_Weather/Orig/IL-94846-2012Fall-2013Spring.csv', skiprows = 8, skipfooter = 15)
# Out:
# C:\Users\nkyam\AppData\Local\Temp\ipykernel_15380\3507900010.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   temp_table = pandas.read_csv('NSW_Weather/Orig/IL-94846-2012Fall-2013Spring.csv', skiprows = 8, skipfooter = 15)

# %%
temp_table
# Out:
#             Date   Time  Temp (F) RH (%) Dewpt (F)  Wind Spd (mph)  \
# 0     2012-10-01  00:51        51     82        46               3
# 1     2012-10-01  01:51        50     89        47               0
# 2     2012-10-01  02:51        50     89        47               0
# 3     2012-10-01  03:51        48     96        47               0
# 4     2012-10-01  04:51        51     89        48               5
# ...          ...    ...       ...    ...       ...             ...
# 4363  2013-03-31  19:51        41     54        26              16
# 4364  2013-03-31  20:51        39     61        27              15
# 4365  2013-03-31  21:51        39     61        27              15
# 4366  2013-03-31  22:51        38     57        24              16
# 4367  2013-03-31  23:51        36     56        22              11
#
#      Wind Direction (deg) Peak Wind Gust(mph) Low Cloud Ht (ft)  \
# 0                      10                   m             30000
# 1                       0                   m             30000
# 2                       0                   m              1000
# 3                       0                   m              2400
# 4                     350                   m             30000
# ...                   ...                 ...               ...
# 4363                  290                  23             15000
# 4364                  290                   m              4000
# 4365                  310                  24              3700
# 4366                  310                  26              3700
# 4367                  320                   m              4000
#
#      Med Cloud Ht (ft) High Cloud Ht (ft)  Visibility (mi) Atm Press (hPa)  \
# 0                    m                  m               10          988.80
# 1                    m                  m               10          988.10
# 2                30000                  m               10          988.10
# 3                30000                  m               10          987.80
# 4                    m                  m               10          988.10
# ...                ...                ...              ...             ...
# 4363             25000                  m               10          985.50
# 4364             15000              20000               10          986.20
# 4365              6000              15000               10          986.50
# 4366              6000              15000               10          987.10
# 4367             25000                  m               10          987.80
#
#      Sea Lev Press (hPa) Altimeter (hPa) Precip (in) Wind Chill (F)  \
# 0                1013.10         1013.20        0.00             NC
# 1                1012.50         1012.50        0.00             NC
# 2                1012.40         1012.50        0.00             NC
# 3                1012.20         1012.20        0.00             NC
# 4                1012.40         1012.50        0.00             NC
# ...                  ...             ...         ...            ...
# 4363             1010.20         1009.80        0.00             33
# 4364             1010.90         1010.50        0.00             31
# 4365             1011.20         1010.80        0.00             31
# 4366             1011.80         1011.50        0.00             29
# 4367             1012.40         1012.20        0.00             28
#
#      Heat Index (F)  Unnamed: 18
# 0                NC          NaN
# 1                NC          NaN
# 2                NC          NaN
# 3                NC          NaN
# 4                NC          NaN
# ...             ...          ...
# 4363             NC          NaN
# 4364             NC          NaN
# 4365             NC          NaN
# 4366             NC          NaN
# 4367             NC          NaN
#
# [4368 rows x 19 columns]

# %% [markdown]
# ### Generate all possible time stamps

# %%
from datetime import timedelta, date

def daterange(date1, date2):
    for n in range(int ((date2 - date1).days) + 1):
        yield date1 + timedelta(n)

# %%
start_dt = date(2012, 10, 1)
end_dt = date(2013, 3, 31)

# %%
# Testing
for dt in daterange(start_dt, end_dt):
    print(dt.strftime("%Y-%m-%d"))
# Out:
# 2012-10-01
# 2012-10-02
# 2012-10-03
# 2012-10-04
# 2012-10-05
